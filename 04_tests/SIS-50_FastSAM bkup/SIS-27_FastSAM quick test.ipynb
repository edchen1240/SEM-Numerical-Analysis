# %% [markdown]
# ## 1.1. Import modules, settings, assign paths, prepare image

# %%
"""
[BLK-0_sandbox.py]
Purpose: 
Author: Meng-Chi Ed Chen
Date: 
Reference:
    1.
    2.

Status: Working.
"""
import os, sys, cv2, torch, importlib
import numpy as np
import pandas as pd
from tabulate import tabulate
from datetime import datetime
import matplotlib.pyplot as plt

sys.path.insert(1, r'D:\01_Floor\a_Ed\09_EECS\10_Python\00_Classes and Functions')
import F02_File as F02_File # type: ignore
from SEMNumericalAnalysis import SNA_M1_Utility as M1UTIL
from SEMNumericalAnalysis import SNA_M2_Image as M2IMG
import SIS_M3_Segmentation as M3SEG



#[2] Settings
crop_image = False

#[2] Assign path.
path_FastSAM_model_pt = r'D:\01_Floor\a_Ed\09_EECS\10_Python\weights\FastSAM-x.pt'
path_img = r'D:\01_Floor\a_Ed\09_EECS\10_Python\03_MatureTools\2024-0828_SEM image segmentation\SIS-09_seg\B859_wtsd.jpg'


#[4] Crop image
if crop_image:
    length = 500
    path_bsn, ext = os.path.splitext(path_img)
    path_img_crop = f'{path_bsn}_crop_{ext}'
    M1UTIL.crop_image_center_square(path_img, length, path_img_crop)
    path_img = path_img_crop

# %% [markdown]
# ## 2.1. Segmentation

# %%
importlib.reload(M3SEG)  # Reload the module to apply changes.

#[7] Segmentation setting list.  
seg_conf = 0.20
seg_ioui = 0.10

#[8] Iterate two list together.
segmentation_results, cnt_seg = M3SEG.segment_single_image(path_img, path_FastSAM_model_pt, seg_conf, seg_ioui)

#[9] Overlap result
font_size = 1
tag_ovlp = f'_7-ovlp(C{seg_conf}, I{seg_ioui}; S{cnt_seg})'
M3SEG.overlap_every_segmentation_results_as_a_single_image(segmentation_results, path_img, font_size, tag_ovlp)
# Out:
# [segment_single_image]
# 0: 1024x1024 35 objects, 6242.9ms
# Speed: 28.8ms preprocess, 6242.9ms inference, 563.6ms postprocess per image at shape (1, 3, 1024, 1024)
# --Converting all segmentation results to numpy array.
#
# [overlap_every_segmentation_results_as_a_single_image] Processing: B859_wtsd.jpg
# dir_save_seg: D:\01_Floor\a_Ed\09_EECS\10_Python\03_MatureTools\2024-0828_SEM image segmentation\SIS-09_seg\B859_wtsd_Seg_7-ovlp(C0.1, I0.1; S35)
# --Directory wasn't exists. Just made one.
# -- [S000] 20946.0 (0.93%)	-- [S001] 43557.0 (1.94%)	-- [S002] 22800.0 (1.01%)	-- [S003] 24921.0 (1.11%)	-- [S004] 34443.0 (1.53%)	-- [S005] 45900.0 (2.04%)	-- [S006] 20366.0 (0.91%)	-- [S007] 16784.0 (0.75%)	-- [S008] 24333.0 (1.08%)	-- [S009] 24802.0 (1.10%)	-- [S010] 18534.0 (0.82%)	-- [S011] 19003.0 (0.84%)	-- [S012] 41466.0 (1.84%)	-- [S013] 29254.0 (1.30%)	-- [S014] 6364.0 (0.28%)	-- [S015] 49573.0 (2.20%)	-- [S016] 2338.0 (0.10%)	-- [S017] 19611.0 (0.87%)	-- [S018] 23140.0 (1.03%)	-- [S019] 25844.0 (1.15%)	-- [S020] 51561.0 (2.29%)	-- [S021] 26388.0 (1.17%)	-- [S022] 44502.0 (1.98%)	-- [S023] 7193.0 (0.32%)	-- [S024] 4608.0 (0.20%)	-- [S025] 36815.0 (1.64%)	-- [S026] 7400.0 (0.33%)	-- [S027] 28524.0 (1.27%)	-- [S028] 29743.0 (1.32%)	-- [S029] 5859.0 (0.26%)	-- [S030] 7564.0 (0.34%)	-- [S031] 1581.0 (0.07%)	-- [S032] 252.0 (0.01%)	-- [S033] 2243475.0 (99.71%)
# Removing unresonablely large segmentation. [S033] 2243475.0(99.71%).
# -- [S034] 4904.0 (0.22%)	-- Overlapped image saved to D:\01_Floor\a_Ed\09_EECS\10_Python\03_MatureTools\2024-0828_SEM image segmentation\SIS-09_seg\B859_wtsd_7-ovlp(C0.1, I0.1; S35).jpg
# 'D:\\01_Floor\\a_Ed\\09_EECS\\10_Python\\03_MatureTools\\2024-0828_SEM image segmentation\\SIS-09_seg\\B859_wtsd_7-ovlp(C0.1, I0.1; S35).jpg'

# %%
importlib.reload(M3SEG)  # Reload the module to apply changes.

#[9] Overlap result
font_size = 1
tag_ovlp = f'_7-ovlp(C{seg_conf}, I{seg_ioui}; S{cnt_seg})'
save_segs = True
M3SEG.overlap_every_segmentation_results_as_a_single_image(segmentation_results, path_img, font_size, tag_ovlp, save_segs)
# Out:
# [overlap_every_segmentation_results_as_a_single_image] Processing: B859_wtsd.jpg
# --Converting all segmentation results to numpy array.
# dir_save_seg: D:\01_Floor\a_Ed\09_EECS\10_Python\03_MatureTools\2024-0828_SEM image segmentation\SIS-09_seg\B859_wtsd_Seg_7-ovlp(C0.2, I0.1; S33)
# --Directory wasn't exists. Just made one.
# -- [S000] 21947.0 (0.98%)	-- [S001] 36027.0 (1.60%)	-- [S002] 45021.0 (2.00%)	-- [S003] 20974.0 (0.93%)	-- [S004] 25489.0 (1.13%)	-- [S005] 19436.0 (0.86%)	-- [S006] 47419.0 (2.11%)	-- [S007] 23998.0 (1.07%)	-- [S008] 17641.0 (0.78%)	-- [S009] 19973.0 (0.89%)	-- [S010] 25915.0 (1.15%)	-- [S011] 30661.0 (1.36%)	-- [S012] 20678.0 (0.92%)	-- [S013] 51496.0 (2.29%)	-- [S014] 24329.0 (1.08%)	-- [S015] 18334.0 (0.81%)	-- [S016] 7885.0 (0.35%)	-- [S017] 38155.0 (1.70%)	-- [S018] 30711.0 (1.36%)	-- [S019] 53395.0 (2.37%)	-- [S020] 43004.0 (1.91%)	-- [S021] 45862.0 (2.04%)	-- [S022] 27130.0 (1.21%)	-- [S023] 7589.0 (0.34%)	-- [S024] 27431.0 (1.22%)	-- [S025] 2336.0 (0.10%)	-- [S026] 29866.0 (1.33%)	-- [S027] 6680.0 (0.30%)	-- [S028] 4576.0 (0.20%)	-- [S029] 1311.0 (0.06%)	-- [S030] 7939.0 (0.35%)	-- [S031] 6369.0 (0.28%)	-- [S032] 2211595.0 (98.29%)
# Removing unresonablely large segmentation. [S032] 2211595.0(98.29%).
# -- Overlapped image saved to D:\01_Floor\a_Ed\09_EECS\10_Python\03_MatureTools\2024-0828_SEM image segmentation\SIS-09_seg\B859_wtsd_7-ovlp(C0.2, I0.1; S33).jpg
# 'D:\\01_Floor\\a_Ed\\09_EECS\\10_Python\\03_MatureTools\\2024-0828_SEM image segmentation\\SIS-09_seg\\B859_wtsd_7-ovlp(C0.2, I0.1; S33).jpg'
